# %%
import numpy as np
from class_trial import StockData

# %%
#KODEX 200 (069500.KS) 2002/10/14
#KOSDAQ 150 (229200.KS) 2015/10/01
#NASDAQ 100 ETF (133690.KS) 2010/10/18
#S&P500 Futures ETF (143850.KS) 2011/07/18
#Treasury Bond Securities ETF - Bonds (114260.KS) 2009/07/29
#KODEX KRW Cash (153130.KS) 2012/02/22
#Money Market ETF (157450.KS) 2012/05/16

tic = ["069500.KS", "229200.KS",
             "133690.KS", "143850.KS",
             "114260.KS", "153130.KS", "157450.KS"
             ]
stock_data = StockData(tic)
data = stock_data.download_data('2000-01-01', '2024-2-19','1d')
# Out:
# c:\Users\kango\Desktop\cqralgo\cqrsite\v3121\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Users\kango\Desktop\cqralgo\cqrsite\v3121\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Users\kango\Desktop\cqralgo\cqrsite\v3121\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# ...

# %%
data.Close.dropna(thresh = 6)
# Out:
# Ticker      069500.KS  114260.KS  133690.KS  143850.KS  153130.KS  157450.KS  \
# Date
# 2012-05-16    24560.0    53490.0    13235.0    13890.0   100800.0   100010.0
# 2012-05-17    24550.0    53505.0    13215.0    13905.0   100830.0   100025.0
# 2012-05-18    23740.0    53550.0    12935.0    13550.0   100835.0   100050.0
# 2012-05-21    23985.0    53500.0    12900.0    13565.0   100850.0   100070.0
# 2012-05-22    24405.0    53545.0    13110.0    13750.0   100860.0   100085.0
# ...               ...        ...        ...        ...        ...        ...
# 2024-02-08    35490.0    59290.0   105210.0    55905.0   108695.0   106060.0
# 2024-02-13    35925.0    59195.0   105900.0    56200.0   108715.0   106060.0
# 2024-02-14    35435.0    59085.0   104975.0    55490.0   108710.0   106070.0
# 2024-02-15    35385.0    59165.0   105960.0    55975.0   108730.0   106085.0
# 2024-02-16    35740.0    59125.0   106425.0    56260.0   108740.0   106100.0
#
# Ticker      229200.KS
# Date
# ...

# %%
#KODEX 200 (069500.KS) 2002/10/14
#Treasury Bond Securities ETF - Bonds (114260.KS) 2009/07/29
#NASDAQ 100 ETF (133690.KS) 2010/10/18
#S&P500 Futures ETF (143850.KS) 2011/07/18
#KODEX KRW Cash (153130.KS) 2012/02/22
#Money Market ETF (157450.KS) 2012/05/16
#KOSDAQ 150 (229200.KS) 2015/10/01
#KODEX, Bonds, NASDAQ, S&P, Cash, MMF, KOSDAQ

df,ret = stock_data.clean()
ret
# Out:
# Ticker      069500.KS  114260.KS  133690.KS  143850.KS  153130.KS  157450.KS  \
# Date
# 2015-10-01   1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
# 2015-10-02   0.993515   0.999731   0.995294   0.995088   1.000049   1.000000
# 2015-10-05   1.001053   1.000895   1.012159   1.013911   1.000000   1.000049
# 2015-10-06   1.009466   0.999732   1.003782   1.009958   1.000148   1.000049
# 2015-10-07   1.015212   0.999284   0.998227   1.004601   1.000099   1.000148
# ...               ...        ...        ...        ...        ...        ...
# 2024-02-08   1.001128   0.999916   1.012170   1.008206   1.000184   1.000141
# 2024-02-13   1.012257   0.998398   1.006558   1.005277   1.000184   1.000000
# 2024-02-14   0.986360   0.998142   0.991265   0.987367   0.999954   1.000094
# 2024-02-15   0.998589   1.001354   1.009383   1.008740   1.000184   1.000141
# 2024-02-16   1.010032   0.999324   1.004388   1.005092   1.000092   1.000141
#
# Ticker      229200.KS
# Date
# ...

# %%
df
# Out:
# Ticker       Date  end of month  year  month  069500.KS  114260.KS  133690.KS  \
# 0      2015-10-01          True  2015     10   1.000000   1.000000   1.000000
# 1      2015-10-02          True  2015     10   0.993515   0.999731   0.995294
# 2      2015-10-05          True  2015     10   1.001053   1.000895   1.012159
# 3      2015-10-06          True  2015     10   1.009466   0.999732   1.003782
# 4      2015-10-07          True  2015     10   1.015212   0.999284   0.998227
# ...           ...           ...   ...    ...        ...        ...        ...
# 2027   2024-02-08          True  2024      2   1.001128   0.999916   1.012170
# 2028   2024-02-13          True  2024      2   1.012257   0.998398   1.006558
# 2029   2024-02-14          True  2024      2   0.986360   0.998142   0.991265
# 2030   2024-02-15          True  2024      2   0.998589   1.001354   1.009383
# 2031   2024-02-16          True  2024      2   1.010032   0.999324   1.004388
#
# ...

# %% [markdown]
# ## 1. Original Halloween

# %%
# Halloween Adjusted 짝수 홀수 11 - 4 월 (아빠)

# (짝수해10월말진입. 홀수해 4월말청산): 주식7(코스닥 30% 코스피20% S&P 20% 나스닥30% 주식비중) 채권3 
# (홀수해 5-10월): 코스닥 30%를 ‘TIGER CD금리투자’(현금)로 교체
# (홀수해11-짝수해4월): 주식5(코덱스200만). 채권5
# (짝수해 5-10월): 주식3(코덱스200만). 채권7

""" Weights """#KOSPI, -, NASDAQ, S&P, -, -, KOSDAQ
odd_buy = np.array([0.2*0.7, (1/3*0.3), 0.3*0.7, 0.2*0.7, (1/3*0.3), (1/3*0.3), 0.3*0.7])
odd_hold = np.array([0.2*0.7, (1/3*0.3), 0.3*0.7, 0.2*0.7, (1/3*0.3), (1/3*0.3), 0.0*0.7])

# %%
halloween = stock_data.algo_original_halloween(odd_buy, odd_hold, 10000000)
# Out:
# Print daily return 2015-10-02 00:00:00
# Print daily return 2015-10-05 00:00:00
# Print daily return 2015-10-06 00:00:00
# Print daily return 2015-10-07 00:00:00
# Print daily return 2015-10-08 00:00:00
# Print daily return 2015-10-12 00:00:00
# Print daily return 2015-10-13 00:00:00
# Print daily return 2015-10-14 00:00:00
# Print daily return 2015-10-15 00:00:00
# Print daily return 2015-10-16 00:00:00
# Print daily return 2015-10-19 00:00:00
# Print daily return 2015-10-20 00:00:00
# Print daily return 2015-10-21 00:00:00
# Print daily return 2015-10-22 00:00:00
# Print daily return 2015-10-23 00:00:00
# Print daily return 2015-10-26 00:00:00
# Print daily return 2015-10-27 00:00:00
# Print daily return 2015-10-28 00:00:00
# Print daily return 2015-10-29 00:00:00
# Print daily return 2015-10-30 00:00:00
# Rebalance 2015-10-30 00:00:00
# Print daily return 2015-11-02 00:00:00
# Print daily return 2015-11-03 00:00:00
# Print daily return 2015-11-04 00:00:00
# ...

# %%
stock_data.results()[0]
# Out:
# Ticker      069500.KS mkt val  114260.KS mkt val  133690.KS mkt val  \
# Date
# 2015-10-01       1.400000e+06       1.000000e+06       2.100000e+06
# 2015-10-02       1.390921e+06       9.997315e+05       2.090117e+06
# 2015-10-05       1.392385e+06       1.000627e+06       2.115531e+06
# 2015-10-06       1.405565e+06       1.000358e+06       2.123532e+06
# 2015-10-07       1.426946e+06       9.996420e+05       2.119767e+06
# ...                       ...                ...                ...
# 2024-02-08       2.928922e+06       1.993560e+06       4.268420e+06
# 2024-02-13       2.964821e+06       1.990365e+06       4.296414e+06
# 2024-02-14       2.924383e+06       1.986667e+06       4.258886e+06
# 2024-02-15       2.920256e+06       1.989357e+06       4.298848e+06
# 2024-02-16       2.949554e+06       1.988012e+06       4.317713e+06
#
# Ticker      143850.KS mkt val  153130.KS mkt val  157450.KS mkt val  \
# Date
# ...

# %%
stock_data

# %%
#KODEX 200 (069500.KS) 2002/10/14
#KOSDAQ 150 (229200.KS) 2015/10/01
#NASDAQ 100 ETF (133690.KS) 2010/10/18
#S&P500 Futures ETF (143850.KS) 2011/07/18
#Treasury Bond Securities ETF - Bonds (114260.KS) 2009/07/29
#KODEX KRW Cash (153130.KS) 2012/02/22
#Money Market ETF (157450.KS) 2012/05/16

#KODEX, Bonds, NASDAQ, S&P, Cash, MMF, KOSDAQ
stock_data.results()[1]
# Out:
# Ticker      069500.KS mkt val  114260.KS mkt val  133690.KS mkt val  \
# Date
# 2015-10-01           0.140000           0.100000           0.210000
# 2015-10-02           0.139455           0.100234           0.209558
# 2015-10-05           0.138945           0.099852           0.211107
# 2015-10-06           0.139769           0.099476           0.211164
# 2015-10-07           0.141562           0.099171           0.210294
# ...                       ...                ...                ...
# 2024-02-08           0.143509           0.097679           0.209140
# 2024-02-13           0.143983           0.096660           0.208650
# 2024-02-14           0.142694           0.096939           0.207811
# 2024-02-15           0.141923           0.096682           0.208921
# 2024-02-16           0.142778           0.096233           0.209006
#
# Ticker      143850.KS mkt val  153130.KS mkt val  157450.KS mkt val  \
# Date
# ...

# %%
a=stock_data.results()[1]

# %%
a
# Out:
# Ticker      069500.KS mkt val  114260.KS mkt val  133690.KS mkt val  \
# Date
# 2015-10-01           0.140000           0.100000           0.210000
# 2015-10-02           0.139455           0.100234           0.209558
# 2015-10-05           0.138945           0.099852           0.211107
# 2015-10-06           0.139769           0.099476           0.211164
# 2015-10-07           0.141562           0.099171           0.210294
# ...                       ...                ...                ...
# 2024-02-08           0.143509           0.097679           0.209140
# 2024-02-13           0.143983           0.096660           0.208650
# 2024-02-14           0.142694           0.096939           0.207811
# 2024-02-15           0.141923           0.096682           0.208921
# 2024-02-16           0.142778           0.096233           0.209006
#
# Ticker      143850.KS mkt val  153130.KS mkt val  157450.KS mkt val  \
# Date
# ...

# %%
# 1. 일별수익률추이
daily_ret = stock_data.daily_ret()
# Out:
# c:\Users\kango\Desktop\cqralgo\cqrsite\portfolio\utilis\class_trial.py:446: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   report['누적수익률'] = self.result['port_val']/self.result['port_val'][0]-1

# %%
daily_ret
# Out:
# Ticker          port_val     일별수익률     누적수익률
# Date
# 2015-10-01  1.000000e+07  0.000000  0.000000
# 2015-10-02  9.973941e+06 -0.002606 -0.002606
# 2015-10-05  1.002114e+07  0.004733  0.002114
# 2015-10-06  1.005632e+07  0.003510  0.005632
# 2015-10-07  1.008003e+07  0.002358  0.008003
# ...                  ...       ...       ...
# 2024-02-08  2.040935e+07  0.008861  1.040935
# 2024-02-13  2.059149e+07  0.008924  1.059149
# 2024-02-14  2.049406e+07 -0.004731  1.049406
# 2024-02-15  2.057639e+07  0.004017  1.057639
# 2024-02-16  2.065836e+07  0.003984  1.065836
#
# [2032 rows x 3 columns]

# %%
# 2. 월별수익률추이
monthly_ret = stock_data.monthly_ret()

# %%
monthly_ret
# Out:
#                월별수익률
# Date
# 2015-10-01  0.000000
# 2015-10-30  0.033310
# 2015-11-30  0.006583
# 2015-12-30 -0.000352
# 2016-01-29 -0.027645
# ...              ...
# 2023-09-27 -0.017728
# 2023-10-31 -0.019189
# 2023-11-30  0.077209
# 2023-12-28  0.042758
# 2024-01-31 -0.016299
#
# [101 rows x 1 columns]

# %%
# 3. 자산별투자비중추이
port_weights = stock_data.portfolio_by_asset_class()
# Out:
# c:\Users\kango\Desktop\cqralgo\cqrsite\portfolio\utilis\class_trial.py:476: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   self.X = asset_perc.applymap(self.to_percentage)

# %%
port_weights[0]
# Out:
# 0.36667533250409556

# %%
port_weights[1]
# Out:
#                  5       3       2       1       0    total  위험자산비중  rebal
# Date
# 2015-10-01   0.00%  35.00%  14.00%  30.00%  21.00%  100.00%   0.00%   True
# 2015-10-02   0.00%  34.90%  13.97%  30.08%  21.05%  100.00%   0.00%  False
# 2015-10-05   0.00%  35.01%  14.10%  29.94%  20.96%  100.00%   0.00%  False
# 2015-10-06   0.00%  35.09%  14.19%  29.84%  20.88%  100.00%   0.00%  False
# 2015-10-07   0.00%  35.19%  14.22%  29.76%  20.83%  100.00%   0.00%  False
# ...            ...     ...     ...     ...     ...      ...     ...    ...
# 2024-02-08  21.49%  35.26%  13.91%  29.33%   0.00%  100.00%  21.49%  False
# 2024-02-13  21.82%  35.26%  13.86%  29.06%   0.00%  100.00%  21.82%  False
# 2024-02-14  22.02%  35.05%  13.75%  29.18%   0.00%  100.00%  22.02%  False
# 2024-02-15  22.02%  35.08%  13.82%  29.08%   0.00%  100.00%  22.02%  False
# 2024-02-16  22.03%  35.18%  13.83%  28.96%   0.00%  100.00%  22.03%  False
#
# [2032 rows x 8 columns]

# %%
a=port_weights[1]

# %%
a
# Out:
#                  5       3       2       1       0    total  위험자산비중  rebal
# Date
# 2015-10-01   0.00%  35.00%  14.00%  30.00%  21.00%  100.00%   0.00%   True
# 2015-10-02   0.00%  34.90%  13.97%  30.08%  21.05%  100.00%   0.00%  False
# 2015-10-05   0.00%  35.01%  14.10%  29.94%  20.96%  100.00%   0.00%  False
# 2015-10-06   0.00%  35.09%  14.19%  29.84%  20.88%  100.00%   0.00%  False
# 2015-10-07   0.00%  35.19%  14.22%  29.76%  20.83%  100.00%   0.00%  False
# ...            ...     ...     ...     ...     ...      ...     ...    ...
# 2024-02-08  21.49%  35.26%  13.91%  29.33%   0.00%  100.00%  21.49%  False
# 2024-02-13  21.82%  35.26%  13.86%  29.06%   0.00%  100.00%  21.82%  False
# 2024-02-14  22.02%  35.05%  13.75%  29.18%   0.00%  100.00%  22.02%  False
# 2024-02-15  22.02%  35.08%  13.82%  29.08%   0.00%  100.00%  22.02%  False
# 2024-02-16  22.03%  35.18%  13.83%  28.96%   0.00%  100.00%  22.03%  False
#
# [2032 rows x 8 columns]

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
# 4. 종목별투자비중추이
stock_data.portfolio_by_ind_assets()
# Out:
# c:\Users\kango\Desktop\cqralgo\cqrsite\portfolio\utilis\class_trial.py:482: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   self.X1 = self.res_pct.iloc[:,:-1].applymap(self.to_percentage)
# Ticker     069500.KS mkt val 114260.KS mkt val 133690.KS mkt val  \
# Date
# 2015-10-01            14.00%            10.00%            21.00%
# 2015-10-02            13.95%            10.02%            20.96%
# 2015-10-05            13.89%             9.99%            21.11%
# 2015-10-06            13.98%             9.95%            21.12%
# 2015-10-07            14.16%             9.92%            21.03%
# ...                      ...               ...               ...
# 2024-02-08            14.35%             9.77%            20.91%
# 2024-02-13            14.40%             9.67%            20.86%
# 2024-02-14            14.27%             9.69%            20.78%
# 2024-02-15            14.19%             9.67%            20.89%
# ...

# %%
stock_data

# %%
# 5. 리밸런싱발생내역
stock_data.rebalance_history()
# Out:
#                  5       3       2       1       0    total  위험자산비중  rebal
# Date
# 2015-10-01   0.00%  35.00%  14.00%  30.00%  21.00%  100.00%   0.00%   True
# 2015-10-30  21.00%  35.00%  14.00%  30.00%   0.00%  100.00%  21.00%   True
# 2015-11-30  21.00%  35.00%  14.00%  30.00%   0.00%  100.00%  21.00%   True
# 2015-12-30  21.00%  35.00%  14.00%  30.00%   0.00%  100.00%  21.00%   True
# 2016-01-29  21.00%  35.00%  14.00%  30.00%   0.00%  100.00%  21.00%   True
# ...            ...     ...     ...     ...     ...      ...     ...    ...
# 2023-09-27   0.00%  35.00%  14.00%  30.00%  21.00%  100.00%   0.00%   True
# 2023-10-31  21.00%  35.00%  14.00%  30.00%   0.00%  100.00%  21.00%   True
# 2023-11-30  21.00%  35.00%  14.00%  30.00%   0.00%  100.00%  21.00%   True
# 2023-12-28  21.00%  35.00%  14.00%  30.00%   0.00%  100.00%  21.00%   True
# 2024-01-31  21.00%  35.00%  14.00%  30.00%   0.00%  100.00%  21.00%   True
#
# [101 rows x 8 columns]

# %% [markdown]
# ## 2. Adjusted Halloween

# %%
#### Halloween Adjusted 짝수 홀수 11 - 4 월 (아빠)

####  (짝수해10월말진입. 홀수해 4월말청산): 주식7(코스닥 30% 코스피20% S&P 20% 나스닥30% 주식비중) 채권3 
####  (홀수해 5-10월): 코스닥 30%를 ‘TIGER CD금리투자’(현금)로 교체
####  (홀수해11-짝수해4월): 주식5(코덱스200만). 채권5
####  (짝수해 5-10월): 주식3(코덱스200만). 채권7

halloween_adj = stock_data.algo1(10000000)

# %%
stock_data.results()[0]
# Out:
# Ticker      069500.KS mkt val  114260.KS mkt val  133690.KS mkt val  \
# Date
# 2015-10-01       1.400000e+06       1.000000e+06       2.100000e+06
# 2015-10-02       1.390921e+06       9.997315e+05       2.090117e+06
# 2015-10-05       1.392385e+06       1.000627e+06       2.115531e+06
# 2015-10-06       1.405565e+06       1.000358e+06       2.123532e+06
# 2015-10-07       1.426946e+06       9.996420e+05       2.119767e+06
# ...                       ...                ...                ...
# 2022-12-23       2.130665e+06       1.618095e+06       3.135772e+06
# 2022-12-26       2.133836e+06       1.617238e+06       3.130782e+06
# 2022-12-27       2.148987e+06       1.614950e+06       3.139763e+06
# 2022-12-28       2.123618e+06       1.613092e+06       3.068660e+06
# 2022-12-29       2.085564e+06       1.612092e+06       3.033733e+06
#
# Ticker      143850.KS mkt val  153130.KS mkt val  157450.KS mkt val  \
# Date
# ...

# %%
stock_data.results()[1]
# Out:
# Ticker      069500.KS mkt val  114260.KS mkt val  133690.KS mkt val  \
# Date
# 2015-10-01           0.140000           0.100000           0.210000
# 2015-10-02           0.139455           0.100234           0.209558
# 2015-10-05           0.138945           0.099852           0.211107
# 2015-10-06           0.139769           0.099476           0.211164
# 2015-10-07           0.141562           0.099171           0.210294
# ...                       ...                ...                ...
# 2022-12-23           0.137392           0.104340           0.202204
# 2022-12-26           0.136962           0.103804           0.200952
# 2022-12-27           0.137220           0.103120           0.200484
# 2022-12-28           0.137465           0.104418           0.198639
# 2022-12-29           0.136420           0.105449           0.198441
#
# Ticker      143850.KS mkt val  153130.KS mkt val  157450.KS mkt val  \
# Date
# ...

# %%
# 1. 일별수익률추이
daily_ret = stock_data.daily_ret()
# Out:
# c:\Users\kango\Desktop\cqralgo\cqrsite\portfolio\utilis\class_trial.py:436: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   report['누적수익률'] = self.result['port_val']/self.result['port_val'][0]-1

# %%
daily_ret
# Out:
# Ticker          port_val     일별수익률     누적수익률
# Date
# 2015-10-01  1.000000e+07  0.000000  0.000000
# 2015-10-02  9.973941e+06 -0.002606 -0.002606
# 2015-10-05  1.002114e+07  0.004733  0.002114
# 2015-10-06  1.005632e+07  0.003510  0.005632
# 2015-10-07  1.008003e+07  0.002358  0.008003
# ...                  ...       ...       ...
# 2022-12-23  1.550796e+07 -0.018065  0.550796
# 2022-12-26  1.557975e+07  0.004629  0.557975
# 2022-12-27  1.566088e+07  0.005208  0.566088
# 2022-12-28  1.544840e+07 -0.013568  0.544840
# 2022-12-29  1.528786e+07 -0.010392  0.528786
#
# [1771 rows x 3 columns]

# %%
# 2. 월별수익률추이
monthly_ret = stock_data.monthly_ret()

# %%
monthly_ret
# Out:
#                월별수익률
# Date
# 2015-10-01  0.000000
# 2015-10-30  0.033310
# 2015-11-30  0.000411
# 2015-12-30 -0.003241
# 2016-01-29 -0.035065
# ...              ...
# 2022-07-29  0.035405
# 2022-08-31 -0.007746
# 2022-09-30 -0.020700
# 2022-10-31  0.014079
# 2022-11-30  0.005068
#
# [87 rows x 1 columns]

# %%
len(stock_data.rebal)
# Out:
# 1771

# %%
# 3. 자산별투자비중추이
port_weights = stock_data.portfolio_by_asset_class()
# Out:
# c:\Users\kango\Desktop\cqralgo\cqrsite\portfolio\utilis\class_trial.py:466: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   self.X = asset_perc.applymap(self.to_percentage)

# %%
port_weights[0]
# Out:
# 0.7220366683812339

# %%
port_weights[1]
# Out:
#                  5       3       2       1       0    total  위험자산비중  rebal
# Date
# 2015-10-01   0.00%  35.00%  14.00%  30.00%  21.00%  100.00%   0.00%   True
# 2015-10-02   0.00%  34.90%  13.97%  30.08%  21.05%  100.00%   0.00%  False
# 2015-10-05   0.00%  35.01%  14.10%  29.94%  20.96%  100.00%   0.00%  False
# 2015-10-06   0.00%  35.09%  14.19%  29.84%  20.88%  100.00%   0.00%  False
# 2015-10-07   0.00%  35.19%  14.22%  29.76%  20.83%  100.00%   0.00%  False
# ...            ...     ...     ...     ...     ...      ...     ...    ...
# 2022-12-23  20.71%  33.96%  14.03%  31.30%   0.00%  100.00%  20.71%  False
# 2022-12-26  21.00%  33.79%  14.05%  31.15%   0.00%  100.00%  21.00%  False
# 2022-12-27  21.20%  33.77%  14.05%  30.98%   0.00%  100.00%  21.20%  False
# 2022-12-28  20.87%  33.61%  14.11%  31.40%   0.00%  100.00%  20.87%  False
# 2022-12-29  20.71%  33.49%  14.08%  31.73%   0.00%  100.00%  20.71%  False
#
# [1771 rows x 8 columns]

# %%
# 4. 종목별투자비중추이
stock_data.portfolio_by_ind_assets()
# Out:
# c:\Users\kango\Desktop\cqralgo\cqrsite\portfolio\utilis\class_trial.py:472: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   self.X1 = self.res_pct.iloc[:,:-1].applymap(self.to_percentage)
# Ticker     069500.KS mkt val 114260.KS mkt val 133690.KS mkt val  \
# Date
# 2015-10-01            14.00%            10.00%            21.00%
# 2015-10-02            13.95%            10.02%            20.96%
# 2015-10-05            13.89%             9.99%            21.11%
# 2015-10-06            13.98%             9.95%            21.12%
# 2015-10-07            14.16%             9.92%            21.03%
# ...                      ...               ...               ...
# 2022-12-23            13.74%            10.43%            20.22%
# 2022-12-26            13.70%            10.38%            20.10%
# 2022-12-27            13.72%            10.31%            20.05%
# 2022-12-28            13.75%            10.44%            19.86%
# ...

# %%
# 5. 리밸런싱발생내역
stock_data.rebalance_history()
# Out:
#                  5       3       2       1       0    total  위험자산비중  rebal
# Date
# 2015-10-01   0.00%  35.00%  14.00%  30.00%  21.00%  100.00%   0.00%   True
# 2015-10-30   0.00%  30.00%  20.00%  50.00%  -0.00%  100.00%   0.00%   True
# 2015-11-30   0.00%  30.00%  20.00%  50.00%  -0.00%  100.00%   0.00%   True
# 2015-12-30   0.00%  30.00%  20.00%  50.00%   0.00%  100.00%   0.00%   True
# 2016-01-29   0.00%  30.00%  20.00%  50.00%   0.00%  100.00%   0.00%   True
# ...            ...     ...     ...     ...     ...      ...     ...    ...
# 2022-07-29   0.00%  15.00%  15.00%  70.00%   0.00%  100.00%   0.00%   True
# 2022-08-31   0.00%  15.00%  15.00%  70.00%   0.00%  100.00%   0.00%   True
# 2022-09-30   0.00%  15.00%  15.00%  70.00%   0.00%  100.00%   0.00%   True
# 2022-10-31  21.00%  35.00%  14.00%  30.00%   0.00%  100.00%  21.00%   True
# 2022-11-30  21.00%  35.00%  14.00%  30.00%   0.00%  100.00%  21.00%   True
#
# [87 rows x 8 columns]

# %% [markdown]
# ## 3. Adjusted with 7

# %%
halloween_adj = stock_data.algo2(10000000)

# %%
stock_data.results()[0]
# Out:
# Ticker      069500.KS mkt val  114260.KS mkt val  133690.KS mkt val  \
# Date
# 2015-10-01       1.400000e+06       1.000000e+06       2.100000e+06
# 2015-10-02       1.390921e+06       9.997315e+05       2.090117e+06
# 2015-10-05       1.392385e+06       1.000627e+06       2.115531e+06
# 2015-10-06       1.405565e+06       1.000358e+06       2.123532e+06
# 2015-10-07       1.426946e+06       9.996420e+05       2.119767e+06
# ...                       ...                ...                ...
# 2022-12-23       2.124580e+06       1.613474e+06       3.126815e+06
# 2022-12-26       2.127742e+06       1.612618e+06       3.121840e+06
# 2022-12-27       2.142850e+06       1.610338e+06       3.130796e+06
# 2022-12-28       2.117553e+06       1.608485e+06       3.059896e+06
# 2022-12-29       2.079608e+06       1.607487e+06       3.025068e+06
#
# Ticker      143850.KS mkt val  153130.KS mkt val  157450.KS mkt val  \
# Date
# ...

# %%
stock_data.results()[1]
# Out:
# Ticker      069500.KS mkt val  114260.KS mkt val  133690.KS mkt val  \
# Date
# 2015-10-01           0.140000           0.100000           0.210000
# 2015-10-02           0.139455           0.100234           0.209558
# 2015-10-05           0.138945           0.099852           0.211107
# 2015-10-06           0.139769           0.099476           0.211164
# 2015-10-07           0.141562           0.099171           0.210294
# ...                       ...                ...                ...
# 2022-12-23           0.137392           0.104340           0.202204
# 2022-12-26           0.136962           0.103804           0.200952
# 2022-12-27           0.137220           0.103120           0.200484
# 2022-12-28           0.137465           0.104418           0.198639
# 2022-12-29           0.136420           0.105449           0.198441
#
# Ticker      143850.KS mkt val  153130.KS mkt val  157450.KS mkt val  \
# Date
# ...

# %%
# 1. 일별수익률추이
daily_ret = stock_data.daily_ret()
# Out:
# c:\Users\kango\Desktop\cqralgo\cqrsite\portfolio\utilis\class_trial.py:436: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   report['누적수익률'] = self.result['port_val']/self.result['port_val'][0]-1

# %%
daily_ret
# Out:
# Ticker          port_val     일별수익률     누적수익률
# Date
# 2015-10-01  1.000000e+07  0.000000  0.000000
# 2015-10-02  9.973941e+06 -0.002606 -0.002606
# 2015-10-05  1.002114e+07  0.004733  0.002114
# 2015-10-06  1.005632e+07  0.003510  0.005632
# 2015-10-07  1.008003e+07  0.002358  0.008003
# ...                  ...       ...       ...
# 2022-12-23  1.546366e+07 -0.018065  0.546366
# 2022-12-26  1.553525e+07  0.004629  0.553525
# 2022-12-27  1.561615e+07  0.005208  0.561615
# 2022-12-28  1.540427e+07 -0.013568  0.540427
# 2022-12-29  1.524419e+07 -0.010392  0.524419
#
# [1771 rows x 3 columns]

# %%
# 2. 월별수익률추이
monthly_ret = stock_data.monthly_ret()

# %%
monthly_ret
# Out:
#                월별수익률
# Date
# 2015-10-01  0.000000
# 2015-10-30  0.033310
# 2015-11-30  0.000411
# 2015-12-30 -0.003241
# 2016-01-29 -0.035065
# ...              ...
# 2022-07-29  0.048974
# 2022-08-31 -0.007746
# 2022-09-30 -0.020700
# 2022-10-31  0.014079
# 2022-11-30  0.005068
#
# [87 rows x 1 columns]

# %%
# 3. 자산별투자비중추이
port_weights = stock_data.portfolio_by_asset_class()
# Out:
# c:\Users\kango\Desktop\cqralgo\cqrsite\portfolio\utilis\class_trial.py:466: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   self.X = asset_perc.applymap(self.to_percentage)

# %%
port_weights[0]
# Out:
# 0.722036668381234

# %%
port_weights[1]
# Out:
#                  5       3       2       1       0    total  위험자산비중  rebal
# Date
# 2015-10-01   0.00%  35.00%  14.00%  30.00%  21.00%  100.00%   0.00%   True
# 2015-10-02   0.00%  34.90%  13.97%  30.08%  21.05%  100.00%   0.00%  False
# 2015-10-05   0.00%  35.01%  14.10%  29.94%  20.96%  100.00%   0.00%  False
# 2015-10-06   0.00%  35.09%  14.19%  29.84%  20.88%  100.00%   0.00%  False
# 2015-10-07   0.00%  35.19%  14.22%  29.76%  20.83%  100.00%   0.00%  False
# ...            ...     ...     ...     ...     ...      ...     ...    ...
# 2022-12-23  20.71%  33.96%  14.03%  31.30%   0.00%  100.00%  20.71%  False
# 2022-12-26  21.00%  33.79%  14.05%  31.15%   0.00%  100.00%  21.00%  False
# 2022-12-27  21.20%  33.77%  14.05%  30.98%   0.00%  100.00%  21.20%  False
# 2022-12-28  20.87%  33.61%  14.11%  31.40%   0.00%  100.00%  20.87%  False
# 2022-12-29  20.71%  33.49%  14.08%  31.73%   0.00%  100.00%  20.71%  False
#
# [1771 rows x 8 columns]

# %%
# 4. 종목별투자비중추이
stock_data.portfolio_by_ind_assets()
# Out:
# c:\Users\kango\Desktop\cqralgo\cqrsite\portfolio\utilis\class_trial.py:472: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   self.X1 = self.res_pct.iloc[:,:-1].applymap(self.to_percentage)
# Ticker     069500.KS mkt val 114260.KS mkt val 133690.KS mkt val  \
# Date
# 2015-10-01            14.00%            10.00%            21.00%
# 2015-10-02            13.95%            10.02%            20.96%
# 2015-10-05            13.89%             9.99%            21.11%
# 2015-10-06            13.98%             9.95%            21.12%
# 2015-10-07            14.16%             9.92%            21.03%
# ...                      ...               ...               ...
# 2022-12-23            13.74%            10.43%            20.22%
# 2022-12-26            13.70%            10.38%            20.10%
# 2022-12-27            13.72%            10.31%            20.05%
# 2022-12-28            13.75%            10.44%            19.86%
# ...

# %%
# 5. 리밸런싱발생내역
stock_data.rebalance_history()
# Out:
#                  5       3       2       1       0    total  위험자산비중  rebal
# Date
# 2015-10-01   0.00%  35.00%  14.00%  30.00%  21.00%  100.00%   0.00%   True
# 2015-10-30   0.00%  30.00%  20.00%  50.00%  -0.00%  100.00%   0.00%   True
# 2015-11-30   0.00%  30.00%  20.00%  50.00%  -0.00%  100.00%   0.00%   True
# 2015-12-30   0.00%  30.00%  20.00%  50.00%   0.00%  100.00%   0.00%   True
# 2016-01-29   0.00%  30.00%  20.00%  50.00%   0.00%  100.00%   0.00%   True
# ...            ...     ...     ...     ...     ...      ...     ...    ...
# 2022-07-29   0.00%  15.00%  15.00%  70.00%   0.00%  100.00%   0.00%   True
# 2022-08-31   0.00%  15.00%  15.00%  70.00%   0.00%  100.00%   0.00%   True
# 2022-09-30   0.00%  15.00%  15.00%  70.00%   0.00%  100.00%   0.00%   True
# 2022-10-31  21.00%  35.00%  14.00%  30.00%   0.00%  100.00%  21.00%   True
# 2022-11-30  21.00%  35.00%  14.00%  30.00%   0.00%  100.00%  21.00%   True
#
# [87 rows x 8 columns]

# %% [markdown]
# ---

# %%
# %matplotlib inline
import quantstats as qs
import webbrowser

# %%
# extend pandas functionality with metrics, etc.
qs.extend_pandas()

# %%
daily_ret.iloc[:,1]
# Out:
# Date
# 2015-10-01    0.000000
# 2015-10-02   -0.002606
# 2015-10-05    0.004733
# 2015-10-06    0.003510
# 2015-10-07    0.002358
#                 ...
# 2022-12-23   -0.018065
# 2022-12-26    0.004629
# 2022-12-27    0.005208
# 2022-12-28   -0.013568
# 2022-12-29   -0.010392
# Name: 일별수익률, Length: 1771, dtype: float64

# %%
daily_ret.iloc[:,1]
# Out:
# Date
# 2015-10-01    0.000000
# 2015-10-02   -0.002606
# 2015-10-05    0.004733
# 2015-10-06    0.003510
# 2015-10-07    0.002358
#                 ...
# 2022-12-23   -0.018065
# 2022-12-26    0.004629
# 2022-12-27    0.005208
# 2022-12-28   -0.013568
# 2022-12-29   -0.010392
# Name: 일별수익률, Length: 1771, dtype: float64

# %%
#stock = qs.utils.download_returns('AAPL')

#qs.reports.plots(daily_ret.iloc[:,1], mode='basic')

qs.reports.html(daily_ret.iloc[:,1], "^KS11", output='./file-name.html')
# Out:
# c:\Users\kango\Desktop\cqralgo\cqrsite\v3121\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# c:\Users\kango\Desktop\cqralgo\cqrsite\v3121\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.prod with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# ...

# %%
qs.reports.html(daily_ret.iloc[:,1], "SPY", output=r'c:\kannie\Halloween_spy.html', title='Halloween_spy')

html_file_path = r'C:\kannie\Halloween_spy.html'
#'c:\\Temp\\kaseoHalloween_spy.html'
# Open the HTML file in the default web browser
# Out:
# c:\Users\kango\Desktop\cqralgo\cqrsite\v3121\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# c:\Users\kango\Desktop\cqralgo\cqrsite\v3121\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.prod with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# ...

# %% [markdown]
# ---

# %%
webbrowser.open(html_file_path)
# Out:
# True

# %%
import yfinance as yf
from datetime import datetime, timedelta

# %%
(datetime.today() - timedelta(1)).strftime('%Y-%m-%d')
# Out:
# '2024-02-19'

# %%
yf.download("AAPL",
            datetime.today().strftime('%Y-%m-%d'),
            interval = '1d', 
            group_by = 'column')
# Out:
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPL']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2024-02-20 -> 2024-02-20)')
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []
